# %% [markdown]
# ## EXERCISES

# %% [markdown]
# #### Exercise 1

# %% [markdown]
# Investigate on the difference between `is` and `==` given the following variables.
# ```python
# a = 2
# b = 2.0
# c = a
#
# Answer: The operator == is used to compare the values of two variables, while is is used to compare their identity in memory whether they refer to the same object.
# ```

# %% [markdown]
# ## CHALLENGES

# %% [markdown]
# #### Challenge 1

# %% [markdown]
# Write a program which repeatedly reads numbers until the user enters "done". Once "done" is entered, print out the total, count, and average of the numbers. If the user enters anything other than a number, detect their mistake using try and except and print an error message and skip to the next number.
#
#     Enter a number: 4
#     Enter a number: 5
#     Enter a number: bad data
#     Invalid input
#     Enter a number: 7
#     Enter a number: done
#     16 3 5.333333333333333
#
# [PEW] E5.1

# %%
total = 0
count = 0

while True:
    user_input = input("Enter a number: ")

   q
    if user_input.lower() == "done":
        break

    try:

        number = float(user_input)
        total += number
        count += 1
    except ValueError:

        print("Invalid input")
        continue


if count > 0:
    average = total / count
    print(total, count, average)
else:
    print("No numbers were entered.")
# Out:
# Enter a number: 5
# Enter a number: 4
# Enter a number: 5
# Enter a number: 0
# Enter a number: q
# Invalid input
# Enter a number: done
# 14.0 4 3.5

# %% [markdown]
# #### Challenge 2

# %% [markdown]
# Write another program that prompts for a list of numbers as above and at the end prints out both the maximum and minimum of the numbers instead of the average.
#
# [PEW] E5.2

# %%
maximum = None
minimum = None

while True:
    user_input = input("Enter a number: ")

    if user_input.lower() == "0":
        break

    try:
        number = float(user_input)


        if maximum is None or number > maximum:
            maximum = number


        if minimum is None or number < minimum:
            minimum = number

    except ValueError:
        print("Invalid input")
        continue

print(maximum, minimum)
# Out:
# Enter a number: 4
# Enter a number: 8
# Enter a number: 0
# 8.0 4.0
